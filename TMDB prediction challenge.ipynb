# %% [markdown]
# ### Importing required libraries

# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# from wordcloud import WordCloud
# from collections import Counter
# from sklearn import preprocessing
# from datetime import datetime
# import ast
# from sklearn.preprocessing import normalize
# from sklearn.model_selection import train_test_split
# from keras import layers
# from keras import models
# from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ###  Loading dataset

# %%
df_train=pd.read_csv("/home/shahules786/datasets/TMDB/train.csv").copy()
df_train=pd.read_csv()

# %% [markdown]
# ### Getting a basic ideas about the data

# %%
df_train.shape
# Out:
# (3000, 23)

# %%
df_test.shape

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
# id                       3000 non-null int64
# belongs_to_collection    604 non-null object
# budget                   3000 non-null int64
# genres                   2993 non-null object
# homepage                 946 non-null object
# imdb_id                  3000 non-null object
# original_language        3000 non-null object
# original_title           3000 non-null object
# overview                 2992 non-null object
# popularity               3000 non-null float64
# poster_path              2999 non-null object
# production_companies     2844 non-null object
# production_countries     2945 non-null object
# release_date             3000 non-null object
# runtime                  2998 non-null float64
# spoken_languages         2980 non-null object
# status                   3000 non-null object
# tagline                  2403 non-null object
# title                    3000 non-null object
# Keywords                 2724 non-null object
# cast                     2987 non-null object
# crew                     2984 non-null object
# revenue                  3000 non-null int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 539.1+ KB

# %%
df_train.head(5)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %%
df_train.describe(include='all')
# Out:
#                  id                              belongs_to_collection  \
# count   3000.000000                                                604
# unique          NaN                                                422
# top             NaN  [{'id': 645, 'name': 'James Bond Collection', ...
# freq            NaN                                                 16
# mean    1500.500000                                                NaN
# std      866.169729                                                NaN
# min        1.000000                                                NaN
# 25%      750.750000                                                NaN
# 50%     1500.500000                                                NaN
# 75%     2250.250000                                                NaN
# max     3000.000000                                                NaN
#
#               budget                         genres  \
# count   3.000000e+03                           2993
# unique           NaN                            872
# top              NaN  [{'id': 18, 'name': 'Drama'}]
# freq             NaN                            266
# mean    2.253133e+07                            NaN
# std     3.702609e+07                            NaN
# min     0.000000e+00                            NaN
# 25%     0.000000e+00                            NaN
# 50%     8.000000e+06                            NaN
# 75%     2.900000e+07                            NaN
# max     3.800000e+08                            NaN
#
#                                  homepage    imdb_id original_language  \
# count                                 946       3000              3000
# unique                                941       3000                36
# top     http://www.transformersmovie.com/  tt0303816                en
# freq                                    4          1              2575
# mean                                  NaN        NaN               NaN
# std                                   NaN        NaN               NaN
# min                                   NaN        NaN               NaN
# 25%                                   NaN        NaN               NaN
# 50%                                   NaN        NaN               NaN
# 75%                                   NaN        NaN               NaN
# max                                   NaN        NaN               NaN
#
#        original_title                                           overview  \
# count            3000                                               2992
# unique           2975                                               2992
# top           Ben-Hur  The Powerpuff Girls Movie tells the origin sto...
# freq                2                                                  1
# mean              NaN                                                NaN
# std               NaN                                                NaN
# min               NaN                                                NaN
# 25%               NaN                                                NaN
# 50%               NaN                                                NaN
# 75%               NaN                                                NaN
# max               NaN                                                NaN
#
#          popularity  ... release_date      runtime  \
# count   3000.000000  ...         3000  2998.000000
# unique          NaN  ...         2398          NaN
# top             NaN  ...      9/10/10          NaN
# freq            NaN  ...            5          NaN
# mean       8.463274  ...          NaN   107.856571
# std       12.104000  ...          NaN    22.086434
# min        0.000001  ...          NaN     0.000000
# 25%        4.018053  ...          NaN    94.000000
# 50%        7.374861  ...          NaN   104.000000
# 75%       10.890983  ...          NaN   118.000000
# max      294.337037  ...          NaN   338.000000
#
#                                 spoken_languages    status  \
# count                                       2980      3000
# unique                                       401         2
# top     [{'iso_639_1': 'en', 'name': 'English'}]  Released
# freq                                        1817      2996
# mean                                         NaN       NaN
# std                                          NaN       NaN
# min                                          NaN       NaN
# 25%                                          NaN       NaN
# 50%                                          NaN       NaN
# 75%                                          NaN       NaN
# max                                          NaN       NaN
#
#                        tagline    title  \
# count                     2403     3000
# unique                    2400     2969
# top     Based on a true story.  Unknown
# freq                         3        2
# mean                       NaN      NaN
# std                        NaN      NaN
# min                        NaN      NaN
# 25%                        NaN      NaN
# 50%                        NaN      NaN
# 75%                        NaN      NaN
# max                        NaN      NaN
#
#                                            Keywords  cast  \
# count                                          2724  2987
# unique                                         2648  2975
# top     [{'id': 10183, 'name': 'independent film'}]    []
# freq                                             27    13
# mean                                            NaN   NaN
# std                                             NaN   NaN
# min                                             NaN   NaN
# 25%                                             NaN   NaN
# 50%                                             NaN   NaN
# 75%                                             NaN   NaN
# max                                             NaN   NaN
#
#                                                      crew       revenue
# count                                                2984  3.000000e+03
# unique                                               2984           NaN
# top     [{'credit_id': '52fe4220c3a36847f8005e57', 'de...           NaN
# freq                                                    1           NaN
# mean                                                  NaN  6.672585e+07
# std                                                   NaN  1.375323e+08
# min                                                   NaN  1.000000e+00
# 25%                                                   NaN  2.379808e+06
# 50%                                                   NaN  1.680707e+07
# 75%                                                   NaN  6.891920e+07
# max                                                   NaN  1.519558e+09
#
# [11 rows x 23 columns]

# %% [markdown]
# ### Missing values

# %%
df_train.isna().sum().sort_values(ascending=False)
# Out:
# belongs_to_collection    2396
# homepage                 2054
# tagline                   597
# Keywords                  276
# production_companies      156
# production_countries       55
# spoken_languages           20
# crew                       16
# cast                       13
# overview                    8
# genres                      7
# runtime                     2
# poster_path                 1
# original_language           0
# budget                      0
# imdb_id                     0
# revenue                     0
# original_title              0
# popularity                  0
# release_date                0
# status                      0
# title                       0
# id                          0
# dtype: int64

# %%
missing=df_train.isna().sum().sort_values(ascending=False)
sns.barplot(missing[:8],missing[:8].index)
plt.show()

# %% [markdown]
# There are many variable with large number of null values,we will inspect those variables first.

# %%
plt.style.use('seaborn')

# %%
import ast
dict_columns = ['belongs_to_collection', 'genres', 'production_companies',
                'production_countries', 'spoken_languages', 'Keywords', 'cast', 'crew']

def text_to_dict(df):
    for column in dict_columns:
        df[column] = df[column].apply(lambda x: {} if pd.isna(x) else ast.literal_eval(x) )
    return df
        
dfx = text_to_dict(df_train)
for col in dict_columns:
       df_train[col]=dfx[col]

# %% [markdown]
# #### belongs to collection

# %% [markdown]
# - belongs_to_collection - Contains the TMDB Id, Name, Movie Poster and Backdrop URL of a movie in JSON format. You can see the Poster and Backdrop Image like this: https://image.tmdb.org/t/p/original/. Example: https://image.tmdb.org/t/p/original//iEhb00TGPucF0b4joM1ieyY026U.jpg

# %%
df_train['belongs_to_collection'].apply(lambda x:len(x) if x!= {} else 0).value_counts()
# Out:
# 0    2396
# 1     604
# Name: belongs_to_collection, dtype: int64

# %% [markdown]
# Only 604 films belong to some collections

# %%
collections=df_train['belongs_to_collection'].apply(lambda x : x[0]['name'] if x!= {} else '?').value_counts()[1:15]
sns.barplot(collections,collections.index)
plt.show()

# %% [markdown]
# We can observe that james bond collection films,friday the 13th,
# The pink panther stands first among the number of films released
# in particular collection series

# %% [markdown]
# ### Tagline

# %% [markdown]
# - tagline : The tagline which was assosiated with the film

# %%
df_train['tagline'].apply(lambda x:1 if x is not np.nan else 0).value_counts()
# Out:
# 1    2403
# 0     597
# Name: tagline, dtype: int64

# %% [markdown]
# - A wordcloud using taglines

# %%
plt.figure(figsize=(10,10))
taglines=' '.join(df_train['tagline'].apply(lambda x:x if x is not np.nan else ''))

wordcloud = WordCloud(max_font_size=None, background_color='white', collocations=False,
                      width=1200, height=1000).generate(taglines)
plt.imshow(wordcloud)
plt.title('Taglines')
plt.axis("off")
plt.show()

# %% [markdown]
# #### Keywords

# %%
keywords=df_train['Keywords'].apply(lambda x: ' '.join(i['name'] for i in x) if x != {} else '')
plt.figure(figsize=(10,10))
data=' '.join(words for words in keywords)
wordcloud = WordCloud(max_font_size=None, background_color='white', collocations=False,
                      width=1200, height=1000).generate(data)
plt.imshow(wordcloud)
plt.title('Taglines')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Production companies

# %% [markdown]
# - The most famous production companies and the number films released by each

# %%
x=df_train['production_companies'].apply(lambda x : [x[i]['name'] for i in range(len(x))] if x != {} else []).values
Counter([i for j in x for i in j]).most_common(20)
# Out:
# [('Warner Bros.', 202),
#  ('Universal Pictures', 188),
#  ('Paramount Pictures', 161),
#  ('Twentieth Century Fox Film Corporation', 138),
#  ('Columbia Pictures', 91),
#  ('Metro-Goldwyn-Mayer (MGM)', 84),
#  ('New Line Cinema', 75),
#  ('Touchstone Pictures', 63),
#  ('Walt Disney Pictures', 62),
#  ('Columbia Pictures Corporation', 61),
#  ('TriStar Pictures', 53),
#  ('Relativity Media', 48),
#  ('Canal+', 46),
#  ('United Artists', 44),
#  ('Miramax Films', 40),
#  ('Village Roadshow Pictures', 36),
#  ('Regency Enterprises', 31),
#  ('BBC Films', 30),
#  ('Dune Entertainment', 30),
#  ('Working Title Films', 30)]

# %% [markdown]
# ### Production countries

# %%
countries=df_train['production_countries'].apply(lambda x: [i['name'] for i in x] if x!={} else []).values
count=Counter([j for i in countries for j in i]).most_common(10)
sns.barplot([val[1] for val in count],[val[0] for val in count])

# %% [markdown]
# - These are the countries in which most films are released.
#   USA stand first and way above
#   from other countries in terms of number of films assosiated with countries.

# %% [markdown]
# ### Spoken languages

# %% [markdown]
# - This indicates the number of languages spoken in a film

# %%
df_train['spoken_languages'].apply(lambda x:len(x) if x !={} else 0).value_counts()
# Out:
# 1    2105
# 2     549
# 3     216
# 4      72
# 5      23
# 0      20
# 7       6
# 6       6
# 8       2
# 9       1
# Name: spoken_languages, dtype: int64

# %% [markdown]
# - we can see that in most films there is only one language spoken in it.
# - Most number of languages spoken in a film is 9.

# %% [markdown]
# Now we will inspect the languages spoken

# %%
lang=df_train['spoken_languages'].apply(lambda x: [i['name'] for i in x] if x != {} else [])
count=Counter([i for j in lang for i in j]).most_common(5)
sns.barplot([val[1] for val in count],[val[0] for val in count])

# %% [markdown]
# - As expected English comes first followed by French

# %% [markdown]
# ### Genre

# %% [markdown]
# - genres : Contains all the Genres Name & TMDB Id in JSON Format

# %% [markdown]
# We will inspect which genre films are most common

# %%
genre=df_train['genres'].apply(lambda x: [i['name'] for i in x] if x != {} else [])
count=Counter([i for j in genre for i in j]).most_common(10)
sns.barplot([val[1] for val in count],[val[0] for val in count])

# %% [markdown]
# - Drama is the most common genre followed by comedy and thrillers.

# %%
dfx = text_to_dict(df_test)
for col in dict_columns:
       df_test[col]=dfx[col]

# %% [markdown]
# ### Revenue

# %% [markdown]
# - This is our target variable.
# - We will inspect the distribution first.

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title('skewed data')
sns.distplot(df_train['revenue'])
plt.subplot(1,2,2)
plt.title('log transformation')
sns.distplot(np.log(df_train['revenue']))
plt.show()

# %% [markdown]
# - The target variable is skewed,so we will log transform it to obtain a standard distribution.

# %%
df_train['log_revenue']=np.log1p(df_train['revenue'])

# %% [markdown]
# - Histogram

# %%
plt.subplots(figsize=(10,5))
plt.subplot(1,2,1)
plt.hist(df_train['revenue'],bins=10,color='g')
plt.title('skewed data')
plt.subplot(1,2,2)
plt.hist(np.log(df_train['revenue']),bins=10,color='g')
plt.title('log transformation')
plt.show()

# %%
df_train['revenue'].describe()
# Out:
# count    3.000000e+03
# mean     6.672585e+07
# std      1.375323e+08
# min      1.000000e+00
# 25%      2.379808e+06
# 50%      1.680707e+07
# 75%      6.891920e+07
# max      1.519558e+09
# Name: revenue, dtype: float64

# %% [markdown]
# ### Budget

# %%
plt.subplots(figsize=(10,5))
plt.subplot(1,2,1)
plt.hist(df_train['budget']+1,bins=10,color='g')
plt.title('skewed data')
plt.subplot(1,2,2)
plt.hist(np.log(df_train['budget']+1),bins=10,color='g')
plt.title('log transformation')
plt.show()

# %% [markdown]
# #### Revenue vs budget

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.scatterplot(df_train['budget'],df_train['revenue'])
plt.subplot(1,2,2)
sns.scatterplot(np.log1p(df_train['budget']),np.log1p(df_train['revenue']))
plt.show()

# %% [markdown]
# - We dont see any linear relationship among budget and revenue.

# %%
df_train['log_budget']=np.log1p(df_train['budget'])
df_test['log_budget']=np.log1p(df_train['budget'])

# %% [markdown]
# ### Popularity

# %%
plt.hist(df_train['popularity'],bins=30,color='violet')
plt.show()

# %% [markdown]
# ### Popularity vs revenue

# %%
sns.scatterplot(df_train['popularity'],df_train['revenue'],color='violet')
plt.show()

# %% [markdown]
# ### Extracting date features

# %%
def date(x):
    x=str(x)
    year=x.split('/')[2]
    if int(year)<19:
        return x[:-2]+'20'+year
    else:
        return x[:-2]+'19'+year
df_train['release_date']=df_train['release_date'].fillna('1/1/90').apply(lambda x: date(x))
df_test['release_date']=df_test['release_date'].fillna('1/1/90').apply(lambda x: date(x))

# %%
#from datetime import datetime
df_train['release_date']=df_train['release_date'].apply(lambda x: datetime.strptime(x,'%m/%d/%Y'))
df_test['release_date']=df_test['release_date'].apply(lambda x: datetime.strptime(x,'%m/%d/%Y'))

# %%
df_train['release_day']=df_train['release_date'].apply(lambda x:x.weekday())
df_train['release_month']=df_train['release_date'].apply(lambda x:x.month)
df_train['release_year']=df_train['release_date'].apply(lambda x:x.year)

# %%
df_test['release_day']=df_test['release_date'].apply(lambda x:x.weekday())
df_test['release_month']=df_test['release_date'].apply(lambda x:x.month)
df_test['release_year']=df_test['release_date'].apply(lambda x:x.year)

# %% [markdown]
# ### Release day of week

# %%
day=df_train['release_day'].value_counts().sort_index()
sns.barplot(day.index,day)
plt.gca().set_xticklabels(["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],rotation='45')
plt.ylabel('No of releases')
# Out:
# Text(0, 0.5, 'No of releases')

# %% [markdown]
# - We can see that most films are released on friday.
# - This might be because of some strategy .

# %% [markdown]
# #### Is there any relation between release day and revenue?

# %%
sns.catplot(x='release_day',y='revenue',data=df_train)
plt.gca().set_xticklabels(["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],rotation='90')
plt.show()

# %% [markdown]
# #### Is there any relation between runtime and revenue?

# %%
sns.catplot(x='release_day',y='runtime',data=df_train)
plt.gca().set_xticklabels(["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],rotation='90')
plt.show()

# %% [markdown]
# #### Which months yeilds the maximum revenue?

# %%
plt.figure(figsize=(10,15))
sns.catplot(x='release_month',y='revenue',data=df_train)
month_lst = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
              'August', 'September', 'October', 'November', 'December']
plt.gca().set_xticklabels(month_lst,rotation='90')
plt.show()

# %% [markdown]
# - The months of April,may and june yeilds maximum revenue.

# %% [markdown]
# ### Year vs revenue

# %%
plt.figure(figsize=(15,8))
yearly=df_train.groupby(df_train['release_year'])['revenue'].agg('mean')
plt.plot(yearly.index,yearly)
plt.xlabel('year')
plt.ylabel("Revenue")
# Out:
# Text(0, 0.5, 'Revenue')

# %% [markdown]
# - Revenue from films seems increasing and decreasing throughout the years.
# - There is a steep increase in revenue after 2017 or so.

# %% [markdown]
# ### Runtime

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.distplot(np.log1p(df_train['runtime'].fillna(0)))

plt.subplot(1,2,2)
sns.scatterplot(np.log1p(df_train['runtime'].fillna(0)),np.log1p(df_train['revenue']))

# %% [markdown]
# ### Homepage

# %%
df_train['homepage'].value_counts().sort_values(ascending=False)[:5]
# Out:
# http://www.transformersmovie.com/               4
# http://www.thehobbit.com/                       2
# http://www.lordoftherings.net/                  2
# http://en.wikipedia.org/wiki/One,_Two,_Three    1
# http://www.righteouskill-themovie.com           1
# Name: homepage, dtype: int64

# %% [markdown]
# #### Inspecting revenue ,budget ,popularity and runtime of each genre

# %%
genres=df_train.loc[df_train['genres'].str.len()==1][['genres','revenue','budget','popularity','runtime']].reset_index(drop=True)
genres['genres']=genres.genres.apply(lambda x :x[0]['name'])

# %%
genres=genres.groupby(genres.genres).agg('mean')

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.barplot(genres['revenue'],genres.index)

plt.subplot(2,2,2)
sns.barplot(genres['budget'],genres.index)

plt.subplot(2,2,3)
sns.barplot(genres['popularity'],genres.index)

plt.subplot(2,2,4)
sns.barplot(genres['runtime'],genres.index)

# %% [markdown]
# ### Crew

# %%
crew=df_train['crew'].apply(lambda x:[i['name'] for i in x] if x != {} else [])
Counter([i for j in crew for i in j]).most_common(15)
# Out:
# [('Avy Kaufman', 50),
#  ('Robert Rodriguez', 44),
#  ('Deborah Aquila', 40),
#  ('James Newton Howard', 39),
#  ('Mary Vernieu', 38),
#  ('Steven Spielberg', 37),
#  ('Luc Besson', 37),
#  ('Jerry Goldsmith', 37),
#  ('Francine Maisler', 35),
#  ('Tricia Wood', 35),
#  ('James Horner', 33),
#  ('Kerry Barden', 32),
#  ('Bob Weinstein', 30),
#  ('Harvey Weinstein', 30),
#  ('Janet Hirshenson', 30)]

# %% [markdown]
# - There are the most fomous and common crew members
# - Number of films in which they appeared is also shown.

# %% [markdown]
# ### Cast

# %%
cast=df_train['cast'].apply(lambda x:[i['name'] for i in x] if x != {} else [])
Counter([i for j in cast for i in j]).most_common(15)
# Out:
# [('Samuel L. Jackson', 30),
#  ('Robert De Niro', 30),
#  ('Morgan Freeman', 27),
#  ('J.K. Simmons', 25),
#  ('Bruce Willis', 25),
#  ('Liam Neeson', 25),
#  ('Susan Sarandon', 25),
#  ('Bruce McGill', 24),
#  ('John Turturro', 24),
#  ('Forest Whitaker', 23),
#  ('Willem Dafoe', 23),
#  ('Bill Murray', 22),
#  ('Owen Wilson', 22),
#  ('Nicolas Cage', 22),
#  ('Sylvester Stallone', 21)]

# %% [markdown]
# - There are the actors that have appeared in most films

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# In reference with [kernel](https://www.kaggle.com/zero92/eda-tmdb-box-office-prediction) by B.H

# %%
def  prepare_data(df):
    df['budget']=np.log1p(df['budget'])
    
    
    df['collection_name']=df['belongs_to_collection'].apply(lambda x: x[0]['name'] if x != {} else 0)
    df['has_homepage']=0
    df.loc[(pd.isnull(df['homepage'])),'has_homepage']=1
    
    le=LabelEncoder()
    le.fit(list(df['collection_name'].fillna('')))
    df['collection_name']=le.transform(df['collection_name'].fillna('').astype(str))
    
    le=LabelEncoder()
    le.fit(list(df['original_language'].fillna('')))
    df['original_language']=le.transform(df['original_language'].fillna('').astype(str))
    
    df['_num_Keywords'] = df['Keywords'].apply(lambda x: len(x) if x != {} else 0)
    df['_num_cast'] = df['cast'].apply(lambda x: len(x) if x != {} else 0)
    
    df['isbelongto_coll']=0
    df.loc[pd.isna(df['belongs_to_collection']),'isbelongto_coll']=1
    
    df['isTaglineNA'] = 0
    df.loc[df['tagline'] == 0 ,"isTaglineNA"] = 1 

    df['isOriginalLanguageEng'] = 0 
    df.loc[ df['original_language'] == "en" ,"isOriginalLanguageEng"] = 1
    
    df['is_original_langen']=0
    df.loc[(df['original_language']=='en'),"is_original_langen"]=1
    
    df['ismovie_released']=1
    df.loc[(df['status']!='Released'),'ismovie_released']=0
    
    df['no_spoken_languages']=df['spoken_languages'].apply(lambda x: len(x))
    df['original_title_letter_count'] = df['original_title'].str.len() 
    df['original_title_word_count'] = df['original_title'].str.split().str.len() 


    df['title_word_count'] = df['title'].str.split().str.len()
    df['overview_word_count'] = df['overview'].str.split().str.len()
    df['tagline_word_count'] = df['tagline'].str.split().str.len()
    
    
    df['collection_id'] = df['belongs_to_collection'].apply(lambda x : np.nan if len(x)==0 else x[0]['id'])
    df['production_countries_count'] = df['production_countries'].apply(lambda x : len(x))
    df['production_companies_count'] = df['production_companies'].apply(lambda x : len(x))
    df['cast_count'] = df['cast'].apply(lambda x : len(x))
    df['crew_count'] = df['crew'].apply(lambda x : len(x))

    df['genders_0_crew'] = df['crew'].apply(lambda x: sum([1 for i in x if i['gender'] == 0]))
    df['genders_1_crew'] = df['crew'].apply(lambda x: sum([1 for i in x if i['gender'] == 1]))
    df['genders_2_crew'] = df['crew'].apply(lambda x: sum([1 for i in x if i['gender'] == 2]))

    for col in  ['genres', 'production_countries', 'spoken_languages', 'production_companies'] :
        df[col] = df[col].map(lambda x: sorted(list(set([n if n in train_dict[col] else col+'_etc' for n in [d['name'] for d in x]])))).map(lambda x: ','.join(map(str, x)))
        temp = df[col].str.get_dummies(sep=',')
        df = pd.concat([df, temp], axis=1, sort=False)
    df.drop(['genres_etc'], axis = 1, inplace = True)
    
    df = df.drop(['belongs_to_collection','genres','homepage','imdb_id','overview','Id'
    ,'poster_path','production_companies','production_countries','release_date','spoken_languages'
    ,'status','title','Keywords','cast','crew','original_language','original_title','tagline', 'collection_id'
    ],axis=1)
    
    df.fillna(value=0.0, inplace = True) 

    return df

# %%
def get_json(df):
    global dict_columns
    result=dict()
    for col in dict_columns:
        d=dict()
        rows=df[col].values
        for row in rows:
            if row is None: continue
            for i in row:
                if i['name'] not in d:
                    d[i['name']]=0
                else:
                    d[i['name']]+=1
            result[col]=d
    return result
    
    

    
train_dict=get_json(df_train)
test_dict=get_json(df_test)

# %%
for col in dict_columns :
    
    remove = []
    train_id = set(list(train_dict[col].keys()))
    test_id = set(list(test_dict[col].keys()))   
    
    remove += list(train_id - test_id) + list(test_id - train_id)
    for i in train_id.union(test_id) - set(remove) :
        if train_dict[col][i] < 10 or i == '' :
            remove += [i]
    for i in remove :
        if i in train_dict[col] :
            del train_dict[col][i]
        if i in test_dict[col] :
            del test_dict[col][i]

# %% [markdown]
# ### Splitting train and test

# %%
df_test['revenue']=np.nan
all_data=prepare_data((pd.concat([df_train,df_test]))).reset_index(drop=True)
train=all_data.loc[:df_train.shape[0]-1,:]
test=all_data.loc[df_train.shape[0]:,:]
print(train.shape)
# Out:
# /usr/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#
# /usr/lib/python3.7/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# (3000, 169)

# %%
train.drop('revenue',axis=1,inplace=True)
# Out:
# /usr/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
y=train['log_revenue']
X=train.drop(['log_revenue'],axis=1)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)

# %% [markdown]
# ### Keras model

# %%
model=models.Sequential()
model.add(layers.Dense(212,activation='relu',input_shape=(X.shape[1],)))
model.add(layers.Dense(212,activation='relu'))
model.add(layers.Dense(1))
model.compile(optimizer='rmsprop',loss='mse',metrics=['mae'])
# Out:
# WARNING:tensorflow:From /usr/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
history=model.fit(X_train,y_train,epochs=10,batch_size=12)
# Out:
# WARNING:tensorflow:From /usr/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 2700/2700 [==============================] - 1s 259us/step - loss: 1993.8289 - mean_absolute_error: 31.1868
# Epoch 2/10
# 2700/2700 [==============================] - 0s 143us/step - loss: 232.1668 - mean_absolute_error: 12.5142
# Epoch 3/10
# 2700/2700 [==============================] - 0s 150us/step - loss: 65.4524 - mean_absolute_error: 6.7558
# Epoch 4/10
# 2700/2700 [==============================] - 0s 174us/step - loss: 25.5185 - mean_absolute_error: 3.9222
# Epoch 5/10
# 2700/2700 [==============================] - 1s 296us/step - loss: 13.9307 - mean_absolute_error: 2.8475
# Epoch 6/10
# 2700/2700 [==============================] - 1s 373us/step - loss: 9.8841 - mean_absolute_error: 2.3481
# Epoch 7/10
# 2700/2700 [==============================] - 1s 373us/step - loss: 8.5917 - mean_absolute_error: 2.1518
# Epoch 8/10
# 2700/2700 [==============================] - 1s 371us/step - loss: 8.0593 - mean_absolute_error: 2.0398
# Epoch 9/10
# 2700/2700 [==============================] - 1s 376us/step - loss: 7.5538 - mean_absolute_error: 1.9622
# Epoch 10/10
# 2700/2700 [==============================] - 1s 372us/step - loss: 7.1279 - mean_absolute_error: 1.8842

# %%
print("accuracy of our model",history.acc)
# Out:
#                                   belongs_to_collection     budget  \
# 2775                                                 {}          0
# 340                                                  {}          0
# 2383  [{'id': 369004, 'name': 'Borsalino Collection'...          0
# 519                                                  {}   32000000
# 1122  [{'id': 104833, 'name': 'Fletch Collection', '...    8000000
# 693                                                  {}    5000000
# 2780                                                 {}   35000000
# 194                                                  {}    4500000
# 821                                                  {}     886000
# 1818  [{'id': 10, 'name': 'Star Wars Collection', 'p...  120000000
# 1733                                                 {}   25000000
# 47                                                   {}   44000000
# 890                                                  {}          0
# 2594                                                 {}          0
# 2201                                                 {}    7000000
# 2947                                                 {}          0
# 936                                                  {}          0
# 2886                                                 {}          0
# 1107                                                 {}   20000000
# 1710                                                 {}   15000000
# 2563                                                 {}    7400000
# 2670                                                 {}          0
# 2285                                                 {}          0
# 1880  [{'id': 748, 'name': 'X-Men Collection', 'post...  210000000
# 2614                                                 {}   49000000
# 920   [{'id': 123255, 'name': 'Prom Night Collection...          0
# 2408                                                 {}   16000000
# 1063  [{'id': 420, 'name': 'The Chronicles of Narnia...  180000000
# 192                                                  {}          0
# 1414                                                 {}   40000000
# ...                                                 ...        ...
# 2880                                                 {}  150000000
# 391                                                  {}    7075038
# 1694                                                 {}     521873
# 982                                                  {}    6700000
# 1083                                                 {}   15000000
# 2959                                                 {}    2300000
# 2446                                                 {}    4500000
# 1542  [{'id': 115840, 'name': 'Would I Lie to You? C...    4000000
# 395                                                  {}          0
# 165                                                  {}          0
# 256                                                  {}   55000000
# 285                                                  {}   25000000
# 2501                                                 {}          0
# 365                                                  {}       7000
# 1185                                                 {}          0
# 25                                                   {}          0
# 2728                                                 {}          0
# 781                                                  {}   13000000
# 866                                                  {}     151000
# 721                                                  {}     800000
# 90    [{'id': 2883, 'name': 'Kill Bill Collection', ...   30000000
# 1840                                                 {}  130000000
# 2650  [{'id': 44215, 'name': 'Stargate SG-1 Collecti...    7000000
# 2130  [{'id': 4246, 'name': 'Scary Movie Collection'...   20000000
# 254                                                  {}      11178
# 2040                                                 {}          0
# 782   [{'id': 264, 'name': 'Back to the Future Colle...   40000000
# 2337                                                 {}          0
# 2138  [{'id': 1709, 'name': 'Planet of the Apes Orig...    1700000
# 1453                                                 {}          0
#
#                                                  genres original_language  \
# 2775  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 340                      [{'id': 35, 'name': 'Comedy'}]                en
# 2383  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...                fr
# 519                       [{'id': 18, 'name': 'Drama'}]                en
# 1122  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...                en
# 693   [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...                en
# 2780  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 194   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 821   [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...                en
# 1818  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...                en
# 1733  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...                fr
# 47    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...                en
# 890   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 2594  [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...                hu
# 2201  [{'id': 37, 'name': 'Western'}, {'id': 53, 'na...                en
# 2947                      [{'id': 18, 'name': 'Drama'}]                en
# 936   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...                ta
# 2886  [{'id': 99, 'name': 'Documentary'}, {'id': 107...                en
# 1107  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...                en
# 1710  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...                en
# 2563  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...                hi
# 2670  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...                en
# 2285  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...                en
# 1880  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...                en
# 2614  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...                en
# 920                      [{'id': 27, 'name': 'Horror'}]                en
# 2408  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...                en
# 1063  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...                en
# 192                      [{'id': 35, 'name': 'Comedy'}]                en
# 1414  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...                en
# ...                                                 ...               ...
# 2880  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...                en
# 391   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...                ru
# 1694  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...                hi
# 982   [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...                es
# 1083  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...                en
# 2959  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...                hi
# 2446  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...                en
# 1542                     [{'id': 35, 'name': 'Comedy'}]                fr
# 395   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 165   [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...                en
# 256   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...                en
# 285   [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...                en
# 2501  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 365   [{'id': 878, 'name': 'Science Fiction'}, {'id'...                en
# 1185  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...                de
# 25    [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...                en
# 2728                      [{'id': 18, 'name': 'Drama'}]                es
# 781   [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...                en
# 866   [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...                el
# 721                       [{'id': 18, 'name': 'Drama'}]                en
# 90    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...                en
# 1840  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 2650  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...                en
# 2130                     [{'id': 35, 'name': 'Comedy'}]                en
# 254   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 2040  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...                en
# 782   [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...                en
# 2337  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...                en
# 2138  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...                en
# 1453  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...                ru
#
#                                          original_title  \
# 2775                     Peace, Love & Misunderstanding
# 340                          What We Did on Our Holiday
# 2383                                          Borsalino
# 519                                          The Master
# 1122                                             Fletch
# 693                                  Kill the Messenger
# 2780                                       Sudden Death
# 194                                 Life During Wartime
# 821                                          Swing Time
# 1818       Star Wars: Episode II - Attack of the Clones
# 1733    Les Aventures extraordinaires d'Adèle Blanc-Sec
# 47                                    The Hateful Eight
# 890                                           Dead Bang
# 2594                                       A Nagy Füzet
# 2201                                         Sweetwater
# 2947                                        Split Image
# 936                                           Papanasam
# 2886                                  Iraq in Fragments
# 1107                                        Hummingbird
# 1710                                   Heartbreak Ridge
# 2563                                 कभी अलविदा ना कहना
# 2670                                           Ceremony
# 2285                                              Boy A
# 1880                              X-Men: The Last Stand
# 2614                                            The One
# 920                       Hello Mary Lou: Prom Night II
# 2408                                                Run
# 1063  The Chronicles of Narnia: The Lion, the Witch ...
# 192                      Absolutely Fabulous: The Movie
# 1414                                     Sweet November
# ...                                                 ...
# 2880                                   White House Down
# 391                                        Время первых
# 1694                                       रमन राघव २.०
# 982                                 Cien años de perdón
# 1083                                       Big Fat Liar
# 2959                                         Jab We Met
# 2446                                          Moby Dick
# 1542                             La vérité si je mens !
# 395                               The Great Buck Howard
# 165                                  Ghosts Can't Do It
# 256                                             Everest
# 285                                      Space Truckers
# 2501                                Hyde Park on Hudson
# 365                                              Primer
# 1185                           In weiter Ferne, so nah!
# 25                                          Dr. Giggles
# 2728                                            Colegas
# 781                                     I Saw the Light
# 866                                    Ποτέ την Κυριακή
# 721                                       The Mudge Boy
# 90                                    Kill Bill: Vol. 1
# 1840                                            Pompeii
# 2650                         Stargate: The Ark of Truth
# 2130                                      Scary Movie 5
# 254                                              Bwakaw
# 2040                                        The Visitor
# 782                          Back to the Future Part II
# 2337                                     Something Wild
# 2138                 Conquest of the Planet of the Apes
# 1453                        Под электрическими облаками
#
#                                                overview  popularity  \
# 2775  A conservative lawyer named Diane takes her tw...    8.359985
# 340   Doug and Abi  and their three children travel ...   11.576578
# 2383  In 1930 Marseilles two small-time crooks join ...    4.471645
# 519   Freddie, a volatile, heavy-drinking veteran wh...    8.074218
# 1122  A veritable chameleon, investigative reporter ...    6.040486
# 693   A reporter becomes the target of a vicious sme...   13.524048
# 2780  International action superstar Jean Claude Van...    5.231580
# 194   Friends, family, and lovers struggle to find l...    3.311392
# 821   Lucky is tricked into missing his wedding to M...    6.507597
# 1818  Ten years after the invasion of Naboo, the gal...   14.072511
# 1733  An adventure set in the early part of the 20th...    6.710598
# 47    Bounty hunters seek shelter from a raging bliz...   20.328822
# 890   Los Angeles homicide detective Jerry Beck sear...    1.698895
# 2594  In a village on the Hungarian border, two youn...    3.485214
# 2201  In the late 1800s, a fanatical religious leade...    5.799861
# 2947  An impressionable young man finds himself lite...    0.185169
# 936   A cinephile tries to protect his family by hid...    0.569463
# 2886  An opus in three parts, Iraq In Fragments offe...    0.541397
# 1107  Homeless and on the run from a military court ...    8.801032
# 1710  A hard-nosed, hard-living Marine gunnery serge...    7.390012
# 2563  Dev and Maya are both married to different peo...    2.372520
# 2670  Sam Davis convinces his former best friend to ...    4.186599
# 2285  The story of a young ex-con Jack, newly releas...    8.374040
# 1880  When a cure is found to treat mutations, lines...    0.867943
# 2614  A sheriff's deputy fights an alternate univers...    9.769047
# 920   When Hamilton High's Prom Queen of 1957, Mary ...    5.383766
# 2408  While conveying a Porsche from L.A. to Atlanti...    5.857368
# 1063  Siblings Lucy, Edmund, Susan and Peter step th...   18.135420
# 192   Edina and Patsy are still oozing glitz and gla...    6.395748
# 1414  Nelson is a man devoted to his advertising car...   14.840318
# ...                                                 ...         ...
# 2880  Capitol Policeman John Cale has just been deni...    9.920223
# 391   March 1965. In the heat of the Cold War, the U...   10.181000
# 1694  Set in present day Mumbai the story follows th...    1.668794
# 982   On a rainy morning six armed men in disguise r...    4.987123
# 1083  Fourteen-year-old Jason Shepherd (Muniz) has a...    4.643981
# 2959  Depressed after the passing of his father, Dha...    3.959411
# 2446  In 1841, young Ishmael signs up for service ab...    4.315830
# 1542  The sentimental and comedic adventures of Eddi...    5.099557
# 395   When a law school dropout answers an advertise...    7.957389
# 165   Elderly Scott kills himself after a heart atta...    0.836108
# 256   Inspired by the incredible events surrounding ...   10.758754
# 285   John Canyon is one of the last independent spa...    3.596317
# 2501  The story of the love affair between FDR and h...    3.724207
# 365   Friends/fledgling entrepreneurs invent a devic...    7.153070
# 1185  The film opens with the angel Cassiel (Otto Sa...    2.958988
# 25    In 1957, Evan Rendell flees after his father i...    1.252367
# 2728  The plot follows the misadventures of two youn...    1.269717
# 781   Singer and songwriter Hank Williams rises to f...    4.654312
# 866   Never on Sunday is a 1960 Greek black-and-whit...    1.879162
# 721   Duncan Mudge, mid-teens, lives apart from his ...    7.137026
# 90    An assassin is shot at the altar by her ruthle...   25.261865
# 1840  Set in 79 A.D., POMPEII tells the epic story o...   12.204174
# 2650  SG-1 searches for an ancient weapon which coul...    9.218164
# 2130  Home with their newly-formed family, happy par...   14.272810
# 254   Bwakaw is a drama-comedy about growing old, an...    0.079287
# 2040  A college professor travels to New York City t...    9.040830
# 782   Marty and Doc are at it again in this wacky se...   13.689855
# 2337  A free-spirited woman "kidnaps" a yuppie for a...    4.737529
# 2138  In a futuristic world that has embraced ape sl...   12.843375
# 1453  Russia 2017. The world could be on the verge o...    0.669890
#
#                                    production_companies  \
# 2775              [{'name': 'Atlas Film', 'id': 17619}]
# 340   [{'name': 'BBC Films', 'id': 288}, {'name': 'L...
# 2383  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 519   [{'name': 'Ghoulardi Film Company', 'id': 178}...
# 1122         [{'name': 'Universal Pictures', 'id': 33}]
# 693   [{'name': 'The Combine', 'id': 27450}, {'name'...
# 2780  [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 194          [{'name': 'Werc Werk Works', 'id': 53303}]
# 821           [{'name': 'RKO Radio Pictures', 'id': 6}]
# 1818                   [{'name': 'Lucasfilm', 'id': 1}]
# 1733  [{'name': 'TF1 Films Productions', 'id': 356},...
# 47    [{'name': 'Double Feature Films', 'id': 215}, ...
# 890   [{'name': 'Lorimar Film Entertainment', 'id': ...
# 2594  [{'name': 'Amour Fou Filmproduktion', 'id': 26...
# 2201  [{'name': 'Kickstart Productions', 'id': 2526}...
# 2947                                                 {}
# 936   [{'name': 'Wide Angle Creations', 'id': 20761}...
# 2886                                                 {}
# 1107                [{'name': 'Lionsgate', 'id': 1632}]
# 1710  [{'name': 'Malpaso Productions', 'id': 171}, {...
# 2563  [{'name': 'Yash Raj Films', 'id': 1569}, {'nam...
# 2670               [{'name': 'NALA Films', 'id': 2088}]
# 2285                   [{'name': 'Film 4', 'id': 2335}]
# 1880  [{'name': 'Ingenious Film Partners', 'id': 289...
# 2614  [{'name': 'Columbia Pictures', 'id': 5}, {'nam...
# 920   [{'name': 'Simcom Limited', 'id': 15059}, {'na...
# 2408  [{'name': 'Hollywood Pictures', 'id': 915}, {'...
# 1063  [{'name': 'Walt Disney', 'id': 5888}, {'name':...
# 192   [{'name': 'Fox Searchlight Pictures', 'id': 43...
# 1414  [{'name': 'Bel Air Entertainment', 'id': 788},...
# ...                                                 ...
# 2880  [{'name': 'Columbia Pictures', 'id': 5}, {'nam...
# 391       [{'name': 'Bazelevs Production', 'id': 1038}]
# 1694            [{'name': 'Phantom Films', 'id': 7435}]
# 982   [{'name': 'Telecinco Cinema', 'id': 2674}, {'n...
# 1083         [{'name': 'Universal Pictures', 'id': 33}]
# 2959  [{'name': 'Shree Ashtavinayak Cinevision Ltd',...
# 2446  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 1542  [{'name': 'France 2 Cinéma', 'id': 83}, {'name...
# 395   [{'name': 'Bristol Bay Productions', 'id': 223...
# 165                                                  {}
# 256   [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 285   [{'name': 'Goldcrest Films International', 'id...
# 2501  [{'name': 'Daybreak Pictures', 'id': 4793}, {'...
# 365                  [{'name': 'Thinkfilm', 'id': 446}]
# 1185  [{'name': 'Road Movies Filmproduktion', 'id': ...
# 25    [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 2728             [{'name': 'Ópalo Films', 'id': 29248}]
# 781   [{'name': 'Bron Studios', 'id': 13240}, {'name...
# 866   [{'name': 'MelinaFilm', 'id': 8526}, {'name': ...
# 721                                                  {}
# 90    [{'name': 'Miramax Films', 'id': 14}, {'name':...
# 1840  [{'name': 'Impact Pictures', 'id': 248}, {'nam...
# 2650  [{'name': 'Metro-Goldwyn-Mayer (MGM)', 'id': 8...
# 2130          [{'name': 'Dimension Films', 'id': 7405}]
# 254   [{'name': 'APT Entertainment', 'id': 8355}, {'...
# 2040          [{'name': 'Overture Films', 'id': 12807}]
# 782   [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 2337  [{'name': 'Orion Pictures', 'id': 41}, {'name'...
# 2138  [{'name': 'Twentieth Century Fox Film Corporat...
# 1453              [{'name': 'MetraFilms', 'id': 10694}]
#
#                                    production_countries  runtime  \
# 2775  [{'iso_3166_1': 'US', 'name': 'United States o...     96.0
# 340    [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]     95.0
# 2383  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...    126.0
# 519   [{'iso_3166_1': 'US', 'name': 'United States o...    137.0
# 1122  [{'iso_3166_1': 'US', 'name': 'United States o...     98.0
# 693   [{'iso_3166_1': 'US', 'name': 'United States o...    112.0
# 2780  [{'iso_3166_1': 'US', 'name': 'United States o...    106.0
# 194   [{'iso_3166_1': 'US', 'name': 'United States o...     97.0
# 821   [{'iso_3166_1': 'US', 'name': 'United States o...    103.0
# 1818  [{'iso_3166_1': 'US', 'name': 'United States o...    142.0
# 1733           [{'iso_3166_1': 'FR', 'name': 'France'}]    105.0
# 47    [{'iso_3166_1': 'US', 'name': 'United States o...    167.0
# 890   [{'iso_3166_1': 'US', 'name': 'United States o...    105.0
# 2594          [{'iso_3166_1': 'HU', 'name': 'Hungary'}]    112.0
# 2201  [{'iso_3166_1': 'US', 'name': 'United States o...     95.0
# 2947                                                 {}    111.0
# 936             [{'iso_3166_1': 'IN', 'name': 'India'}]    181.0
# 2886                                                 {}     94.0
# 1107  [{'iso_3166_1': 'US', 'name': 'United States o...    100.0
# 1710  [{'iso_3166_1': 'US', 'name': 'United States o...    130.0
# 2563            [{'iso_3166_1': 'IN', 'name': 'India'}]    193.0
# 2670  [{'iso_3166_1': 'US', 'name': 'United States o...     89.0
# 2285   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]    100.0
# 1880  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...    104.0
# 2614  [{'iso_3166_1': 'US', 'name': 'United States o...     87.0
# 920            [{'iso_3166_1': 'CA', 'name': 'Canada'}]     97.0
# 2408  [{'iso_3166_1': 'US', 'name': 'United States o...     91.0
# 1063  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...    143.0
# 192    [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]     91.0
# 1414  [{'iso_3166_1': 'US', 'name': 'United States o...    119.0
# ...                                                 ...      ...
# 2880  [{'iso_3166_1': 'US', 'name': 'United States o...    131.0
# 391            [{'iso_3166_1': 'RU', 'name': 'Russia'}]    140.0
# 1694            [{'iso_3166_1': 'IN', 'name': 'India'}]    127.0
# 982   [{'iso_3166_1': 'AR', 'name': 'Argentina'}, {'...     96.0
# 1083  [{'iso_3166_1': 'US', 'name': 'United States o...     88.0
# 2959            [{'iso_3166_1': 'IN', 'name': 'India'}]    145.0
# 2446  [{'iso_3166_1': 'US', 'name': 'United States o...    116.0
# 1542           [{'iso_3166_1': 'FR', 'name': 'France'}]    100.0
# 395   [{'iso_3166_1': 'US', 'name': 'United States o...     87.0
# 165   [{'iso_3166_1': 'US', 'name': 'United States o...     90.0
# 256   [{'iso_3166_1': 'IS', 'name': 'Iceland'}, {'is...    121.0
# 285   [{'iso_3166_1': 'IE', 'name': 'Ireland'}, {'is...     95.0
# 2501   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]     94.0
# 365   [{'iso_3166_1': 'US', 'name': 'United States o...     77.0
# 1185          [{'iso_3166_1': 'DE', 'name': 'Germany'}]    144.0
# 25    [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...     95.0
# 2728            [{'iso_3166_1': 'ES', 'name': 'Spain'}]    117.0
# 781   [{'iso_3166_1': 'US', 'name': 'United States o...    123.0
# 866   [{'iso_3166_1': 'GR', 'name': 'Greece'}, {'iso...     91.0
# 721   [{'iso_3166_1': 'US', 'name': 'United States o...     94.0
# 90    [{'iso_3166_1': 'US', 'name': 'United States o...    111.0
# 1840  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...    105.0
# 2650  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...     97.0
# 2130  [{'iso_3166_1': 'US', 'name': 'United States o...     86.0
# 254       [{'iso_3166_1': 'PH', 'name': 'Philippines'}]    104.0
# 2040  [{'iso_3166_1': 'US', 'name': 'United States o...    104.0
# 782   [{'iso_3166_1': 'US', 'name': 'United States o...    108.0
# 2337  [{'iso_3166_1': 'US', 'name': 'United States o...    113.0
# 2138  [{'iso_3166_1': 'US', 'name': 'United States o...     88.0
# 1453           [{'iso_3166_1': 'RU', 'name': 'Russia'}]    137.0
#
#                                        spoken_languages  \
# 2775           [{'iso_639_1': 'en', 'name': 'English'}]
# 340            [{'iso_639_1': 'en', 'name': 'English'}]
# 2383  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 519            [{'iso_639_1': 'en', 'name': 'English'}]
# 1122           [{'iso_639_1': 'en', 'name': 'English'}]
# 693            [{'iso_639_1': 'en', 'name': 'English'}]
# 2780           [{'iso_639_1': 'en', 'name': 'English'}]
# 194            [{'iso_639_1': 'en', 'name': 'English'}]
# 821            [{'iso_639_1': 'en', 'name': 'English'}]
# 1818           [{'iso_639_1': 'en', 'name': 'English'}]
# 1733          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 47    [{'iso_639_1': 'es', 'name': 'Español'}, {'iso...
# 890            [{'iso_639_1': 'en', 'name': 'English'}]
# 2594  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 2201           [{'iso_639_1': 'en', 'name': 'English'}]
# 2947           [{'iso_639_1': 'en', 'name': 'English'}]
# 936              [{'iso_639_1': 'ta', 'name': 'தமிழ்'}]
# 2886  [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...
# 1107           [{'iso_639_1': 'en', 'name': 'English'}]
# 1710  [{'iso_639_1': 'es', 'name': 'Español'}, {'iso...
# 2563  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2670           [{'iso_639_1': 'en', 'name': 'English'}]
# 2285           [{'iso_639_1': 'en', 'name': 'English'}]
# 1880           [{'iso_639_1': 'en', 'name': 'English'}]
# 2614           [{'iso_639_1': 'en', 'name': 'English'}]
# 920            [{'iso_639_1': 'en', 'name': 'English'}]
# 2408           [{'iso_639_1': 'en', 'name': 'English'}]
# 1063  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 192            [{'iso_639_1': 'en', 'name': 'English'}]
# 1414           [{'iso_639_1': 'en', 'name': 'English'}]
# ...                                                 ...
# 2880           [{'iso_639_1': 'en', 'name': 'English'}]
# 391            [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 1694            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 982            [{'iso_639_1': 'es', 'name': 'Español'}]
# 1083  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2959  [{'iso_639_1': 'hi', 'name': 'हिन्दी'}, {'iso_...
# 2446           [{'iso_639_1': 'en', 'name': 'English'}]
# 1542          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 395            [{'iso_639_1': 'en', 'name': 'English'}]
# 165            [{'iso_639_1': 'en', 'name': 'English'}]
# 256            [{'iso_639_1': 'en', 'name': 'English'}]
# 285            [{'iso_639_1': 'en', 'name': 'English'}]
# 2501           [{'iso_639_1': 'en', 'name': 'English'}]
# 365            [{'iso_639_1': 'en', 'name': 'English'}]
# 1185  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 25             [{'iso_639_1': 'en', 'name': 'English'}]
# 2728           [{'iso_639_1': 'es', 'name': 'Español'}]
# 781            [{'iso_639_1': 'en', 'name': 'English'}]
# 866   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 721            [{'iso_639_1': 'en', 'name': 'English'}]
# 90    [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 1840           [{'iso_639_1': 'en', 'name': 'English'}]
# 2650           [{'iso_639_1': 'en', 'name': 'English'}]
# 2130           [{'iso_639_1': 'en', 'name': 'English'}]
# 254                   [{'iso_639_1': 'tl', 'name': ''}]
# 2040  [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...
# 782            [{'iso_639_1': 'en', 'name': 'English'}]
# 2337           [{'iso_639_1': 'en', 'name': 'English'}]
# 2138           [{'iso_639_1': 'en', 'name': 'English'}]
# 1453           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
#
#                                                 tagline  \
# 2775               Life is a journey. Family is a trip.
# 340                                                 NaN
# 2383                                                NaN
# 519                             Every Man Needs a Guide
# 1122  Meet the only guy who changes his identity mor...
# 693                     Can you keep a national secret?
# 2780                         Terror goes into overtime.
# 194                                                 NaN
# 821        A glorious songburst of gaiety and laughter!
# 1818  A Jedi Shall Not Know Anger. Nor Hatred. Nor L...
# 1733                                                NaN
# 47     No one comes up here without a damn good reason.
# 890     For one cop this isn't just a case. It's a war.
# 2594                                                NaN
# 2201                                  Revenge is Sweet.
# 2947  In the name of God, they brainwashed him and s...
# 936                                                 NaN
# 2886                                                NaN
# 1107                 All roads don't lead to salvation.
# 1710                             ...the scars run deep.
# 2563            A Love.... That Broke All Relationships
# 2670  He's the love of her life. She just doesn't kn...
# 2285                                                NaN
# 1880                                       Take a Stand
# 2614    Stealing the power of the universes one by one.
# 920                      You Can't Keep a Bad Girl Down
# 2408  Pursued by the mob, Hunted by the police...Luc...
# 1063                  Evil Has Reigned For 100 Years...
# 192                                                 NaN
# 1414  She Just Needed A Month To Change His Life For...
# ...                                                 ...
# 2880                  It will start like any other day.
# 391              So far from home, so close to disaster
# 1694                                                NaN
# 982                                  Who can you trust?
# 1083                       The truth is never overrated
# 2959                                                NaN
# 2446  From the immortal adventure classic...of whali...
# 1542                                         La verite!
# 395                       Greatness is a state of mind.
# 165             Only her desire can make him rise again
# 256                                   The Storm Awaits.
# 285                                   Earth's Only Hope
# 2501  The President. The First Lady. The King. The Q...
# 365                  What happens if it actually works?
# 1185                     Your favorite Angels are back!
# 25                    The Doctor is out... of his mind.
# 2728           They are more than friends, they are ...
# 781                          The story of Hank Williams
# 866               The Happy Street-Walker of Piraeus...
# 721                                                 NaN
# 90                                     Go for the kill.
# 1840                             No warning. No escape.
# 2650  The lines have been drawn. The battle has been...
# 2130                  Evil is coming. Bring protection.
# 254             In life, you only need one true friend.
# 2040                          Connection is everything.
# 782      Roads? Where we're going, we don't need roads!
# 2337  Something Different. Something Daring. Somethi...
# 2138  All new! The revolt of the apes. The most awes...
# 1453                                                NaN
#
#                                                   title  \
# 2775                     Peace, Love & Misunderstanding
# 340                          What We Did on Our Holiday
# 2383                                          Borsalino
# 519                                          The Master
# 1122                                             Fletch
# 693                                  Kill the Messenger
# 2780                                       Sudden Death
# 194                                 Life During Wartime
# 821                                          Swing Time
# 1818       Star Wars: Episode II - Attack of the Clones
# 1733    The Extraordinary Adventures of Adèle Blanc-Sec
# 47                                    The Hateful Eight
# 890                                           Dead Bang
# 2594                                       The Notebook
# 2201                                         Sweetwater
# 2947                                        Split Image
# 936                                           Papanasam
# 2886                                  Iraq in Fragments
# 1107                                        Hummingbird
# 1710                                   Heartbreak Ridge
# 2563                             Kabhi Alvida Naa Kehna
# 2670                                           Ceremony
# 2285                                              Boy A
# 1880                              X-Men: The Last Stand
# 2614                                            The One
# 920                       Hello Mary Lou: Prom Night II
# 2408                                                Run
# 1063  The Chronicles of Narnia: The Lion, the Witch ...
# 192                      Absolutely Fabulous: The Movie
# 1414                                     Sweet November
# ...                                                 ...
# 2880                                   White House Down
# 391                                     The Spacewalker
# 1694                                   Raman Raghav 2.0
# 982                               To Steal from a Thief
# 1083                                       Big Fat Liar
# 2959                                         Jab We Met
# 2446                                          Moby Dick
# 1542                             La vérité si je mens !
# 395                               The Great Buck Howard
# 165                                  Ghosts Can't Do It
# 256                                             Everest
# 285                                      Space Truckers
# 2501                                Hyde Park on Hudson
# 365                                              Primer
# 1185                                 Faraway, So Close!
# 25                                          Dr. Giggles
# 2728                                            Colegas
# 781                                     I Saw the Light
# 866                                     Never on Sunday
# 721                                       The Mudge Boy
# 90                                    Kill Bill: Vol. 1
# 1840                                            Pompeii
# 2650                         Stargate: The Ark of Truth
# 2130                                      Scary Movie 5
# 254                                           Voracious
# 2040                                        The Visitor
# 782                          Back to the Future Part II
# 2337                                     Something Wild
# 2138                 Conquest of the Planet of the Apes
# 1453                              Under Electric Clouds
#
#                                                Keywords  \
# 2775                                                 {}
# 340   [{'id': 6876, 'name': 'vacation'}, {'id': 1803...
# 2383                                                 {}
# 519   [{'id': 447, 'name': 'post traumatic stress  d...
# 1122  [{'id': 736, 'name': 'journalist'}, {'id': 180...
# 693                 [{'id': 5565, 'name': 'biography'}]
# 2780  [{'id': 949, 'name': 'terrorist'}, {'id': 1562...
# 194   [{'id': 10123, 'name': 'dark comedy'}, {'id': ...
# 821   [{'id': 4344, 'name': 'musical'}, {'id': 10106...
# 1818  [{'id': 1399, 'name': 'senate'}, {'id': 5340, ...
# 1733  [{'id': 293, 'name': 'female nudity'}, {'id': ...
# 47    [{'id': 801, 'name': 'bounty hunter'}, {'id': ...
# 890   [{'id': 376, 'name': 'neo-nazi'}, {'id': 1981,...
# 2594                                                 {}
# 2201  [{'id': 1508, 'name': 'new mexico'}, {'id': 96...
# 2947                                                 {}
# 936   [{'id': 6139, 'name': 'innocence'}, {'id': 974...
# 2886  [{'id': 5894, 'name': 'bagdad'}, {'id': 5939, ...
# 1107  [{'id': 960, 'name': 'homeless person'}, {'id'...
# 1710  [{'id': 2999, 'name': 'recruit'}, {'id': 3776,...
# 2563  [{'id': 596, 'name': 'adultery'}, {'id': 34094...
# 2670  [{'id': 6167, 'name': 'engagement'}, {'id': 85...
# 2285  [{'id': 293, 'name': 'female nudity'}, {'id': ...
# 1880  [{'id': 1852, 'name': 'mutant'}, {'id': 8828, ...
# 2614             [{'id': 851, 'name': 'dual identity'}]
# 920   [{'id': 1227, 'name': 'cemetery'}, {'id': 1326...
# 2408         [{'id': 210386, 'name': 'man on the run'}]
# 1063  [{'id': 83, 'name': 'saving the world'}, {'id'...
# 192   [{'id': 919, 'name': 'smoking'}, {'id': 10988,...
# 1414  [{'id': 1022, 'name': 'workaholic'}, {'id': 59...
# ...                                                 ...
# 2880  [{'id': 840, 'name': 'usa president'}, {'id': ...
# 391   [{'id': 14626, 'name': 'astronaut'}, {'id': 19...
# 1694  [{'id': 10024, 'name': 'psychopathic killer'},...
# 982   [{'id': 732, 'name': 'coma'}, {'id': 6086, 'na...
# 1083  [{'id': 776, 'name': 'screenplay'}, {'id': 887...
# 2959  [{'id': 2038, 'name': 'love of one's life'}, {...
# 2446  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 1542                                                 {}
# 395   [{'id': 2594, 'name': 'magic show'}, {'id': 36...
# 165                                                  {}
# 256   [{'id': 1262, 'name': 'mountain'}, {'id': 3373...
# 285   [{'id': 1373, 'name': 'killer robot'}, {'id': ...
# 2501  [{'id': 2011, 'name': 'queen'}, {'id': 6540, '...
# 365   [{'id': 1448, 'name': 'distrust'}, {'id': 2101...
# 1185  [{'id': 220, 'name': 'berlin'}, {'id': 290, 'n...
# 25                                                   {}
# 2728  [{'id': 6054, 'name': 'friendship'}, {'id': 14...
# 781   [{'id': 727, 'name': 'country music'}, {'id': ...
# 866   [{'id': 549, 'name': 'prostitute'}, {'id': 120...
# 721   [{'id': 2479, 'name': 'chicken'}, {'id': 6733,...
# 90    [{'id': 233, 'name': 'japan'}, {'id': 732, 'na...
# 1840  [{'id': 1394, 'name': 'gladiator'}, {'id': 139...
# 2650  [{'id': 3417, 'name': 'wormhole'}, {'id': 3801...
# 2130  [{'id': 9663, 'name': 'sequel'}, {'id': 9755, ...
# 254   [{'id': 4694, 'name': 'staged death'}, {'id': ...
# 2040  [{'id': 933, 'name': 'michigan'}, {'id': 1439,...
# 782   [{'id': 390, 'name': 'skateboarding'}, {'id': ...
# 2337  [{'id': 242, 'name': 'new york'}, {'id': 293, ...
# 2138  [{'id': 291, 'name': 'circus'}, {'id': 2551, '...
# 1453                                                 {}
#
#                                                    cast  \
# 2775  [{'cast_id': 13, 'character': 'Grace', 'credit...
# 340   [{'cast_id': 4, 'character': 'Doug McLeod', 'c...
# 2383  [{'cast_id': 1, 'character': 'Fran√ßois Capell...
# 519   [{'cast_id': 4, 'character': 'Freddie Quell', ...
# 1122  [{'cast_id': 1, 'character': 'Irwin 'Fletch' F...
# 693   [{'cast_id': 8, 'character': 'Gary Webb', 'cre...
# 2780  [{'cast_id': 1, 'character': 'Darren Francis T...
# 194   [{'cast_id': 6, 'character': 'Helen', 'credit_...
# 821   [{'cast_id': 1, 'character': 'John "Lucky" Gar...
# 1818  [{'cast_id': 7, 'character': 'Obi Wan Kenobi',...
# 1733  [{'cast_id': 8, 'character': 'Ad√®le Blanc-Sec...
# 47    [{'cast_id': 22, 'character': 'Major Marquis W...
# 890   [{'cast_id': 4, 'character': 'Jerry Beck', 'cr...
# 2594  [{'cast_id': 6, 'character': '', 'credit_id': ...
# 2201  [{'cast_id': 1, 'character': 'Sheriff Jackson'...
# 2947  [{'cast_id': 1, 'character': 'Danny 'Joshua' S...
# 936   [{'cast_id': 0, 'character': 'Suyambulingam', ...
# 2886                                                 []
# 1107  [{'cast_id': 5, 'character': 'Joey Jones', 'cr...
# 1710  [{'cast_id': 1, 'character': 'Gunnery Sgt. Tom...
# 2563  [{'cast_id': 1, 'character': 'Dev Saran', 'cre...
# 2670  [{'cast_id': 1002, 'character': 'Zoe', 'credit...
# 2285  [{'cast_id': 1, 'character': 'Jack Burridge', ...
# 1880  [{'cast_id': 4, 'character': 'Logan / Wolverin...
# 2614  [{'cast_id': 13, 'character': 'Gabe Law / Gabr...
# 920   [{'cast_id': 2, 'character': 'Bill Nordham', '...
# 2408  [{'cast_id': 1, 'character': 'Charlie Farrow',...
# 1063  [{'cast_id': 5, 'character': 'Peter Pevensie',...
# 192   [{'cast_id': 1, 'character': 'Edina Monsoon', ...
# 1414  [{'cast_id': 15, 'character': 'Nelson', 'credi...
# ...                                                 ...
# 2880  [{'cast_id': 9, 'character': 'Cale', 'credit_i...
# 391   [{'cast_id': 3, 'character': 'Alexey Leonov', ...
# 1694  [{'cast_id': 6, 'character': 'Ramanna (Raman)'...
# 982   [{'cast_id': 2, 'character': 'Gallego', 'credi...
# 1083  [{'cast_id': 1, 'character': 'Jason Shepherd',...
# 2959  [{'cast_id': 9, 'character': 'Aditya Kashyap',...
# 2446  [{'cast_id': 11, 'character': 'Captain Ahab', ...
# 1542  [{'cast_id': 2, 'character': 'Eddie Vuibert', ...
# 395   [{'cast_id': 2, 'character': 'Buck Howard', 'c...
# 165   [{'cast_id': 1, 'character': 'Katie O'Dare Sco...
# 256   [{'cast_id': 1, 'character': 'Rob Hall', 'cred...
# 285   [{'cast_id': 1, 'character': 'John Canyon', 'c...
# 2501  [{'cast_id': 3, 'character': 'Franklin D. Roos...
# 365   [{'cast_id': 1, 'character': 'Aaron', 'credit_...
# 1185  [{'cast_id': 1, 'character': 'Cassiel', 'credi...
# 25    [{'cast_id': 2, 'character': 'Dr. Evan Rendell...
# 2728  [{'cast_id': 9, 'character': 'Antonio', 'credi...
# 781   [{'cast_id': 1, 'character': 'Hank Williams', ...
# 866   [{'cast_id': 1, 'character': 'Ilya', 'credit_i...
# 721   [{'cast_id': 2, 'character': 'Duncan Mudge', '...
# 90    [{'cast_id': 3, 'character': 'Beatrix 'The Bri...
# 1840  [{'cast_id': 3, 'character': 'Milo', 'credit_i...
# 2650  [{'cast_id': 9, 'character': 'Cameron Mitchell...
# 2130  [{'cast_id': 6, 'character': 'Dan Sanders', 'c...
# 254   [{'cast_id': 16, 'character': 'Rene', 'credit_...
# 2040  [{'cast_id': 3, 'character': 'Prof. Walter Val...
# 782   [{'cast_id': 25, 'character': 'Marty McFly Sr....
# 2337  [{'cast_id': 1, 'character': 'Charles Driggs',...
# 2138  [{'cast_id': 8, 'character': 'Caesar', 'credit...
# 1453  [{'cast_id': 5, 'character': '', 'credit_id': ...
#
#                                                    crew  log_budget  \
# 2775  [{'credit_id': '52fe4a169251416c750dd3e1', 'de...    0.000000
# 340   [{'credit_id': '539e4d040e0a2603c00000cd', 'de...    0.000000
# 2383  [{'credit_id': '531cd71cc3a3685c31006e82', 'de...    0.000000
# 519   [{'credit_id': '52fe47a0c3a368484e0d169f', 'de...   17.281246
# 1122  [{'credit_id': '52fe4526c3a36847f80bf227', 'de...   15.894952
# 693   [{'credit_id': '52fe4f0dc3a36847f82b9e77', 'de...   15.424949
# 2780  [{'credit_id': '52fe44dbc3a36847f80ae0f1', 'de...   17.370859
# 194   [{'credit_id': '54ba422f9251414859003360', 'de...   15.319588
# 821   [{'credit_id': '564c1b62c3a3686035005aa7', 'de...   13.694473
# 1818  [{'credit_id': '52fe431fc3a36847f803bd8b', 'de...   18.603002
# 1733  [{'credit_id': '52fe45a89251416c91039d6f', 'de...   17.034386
# 47    [{'credit_id': '538aa95ec3a368714e0005b3', 'de...   17.599700
# 890   [{'credit_id': '52fe43e3c3a36847f80764a3', 'de...    0.000000
# 2594  [{'credit_id': '52fe4da39251416c9111d105', 'de...    0.000000
# 2201  [{'credit_id': '52fe4bfc9251416c910ebd8f', 'de...   15.761421
# 2947  [{'credit_id': '52fe4842c3a36847f815e821', 'de...    0.000000
# 936   [{'credit_id': '55099d4892514110ca003ae9', 'de...    0.000000
# 2886  [{'credit_id': '52fe45639251416c910307db', 'de...    0.000000
# 1107  [{'credit_id': '52fe4c16c3a368484e1a6435', 'de...   16.811243
# 1710  [{'credit_id': '52fe43089251416c75000c8f', 'de...   16.523561
# 2563  [{'credit_id': '52fe45ee9251416c75067637', 'de...   15.816991
# 2670  [{'credit_id': '5692bb1f925141425700066a', 'de...    0.000000
# 2285  [{'credit_id': '548d70c1c3a3684ea10038e2', 'de...    0.000000
# 1880  [{'credit_id': '538d82720e0a26670e005e83', 'de...   19.162618
# 2614  [{'credit_id': '598ee621c3a368747300f38f', 'de...   17.707331
# 920   [{'credit_id': '533675bf9251417d9b00095c', 'de...    0.000000
# 2408  [{'credit_id': '52fe4755c3a36847f812fda5', 'de...   16.588099
# 1063  [{'credit_id': '52fe4240c3a36847f800fd4f', 'de...   19.008467
# 192   [{'credit_id': '56a9256c9251417dcb001158', 'de...    0.000000
# 1414  [{'credit_id': '52fe4322c3a36847f803cc09', 'de...   17.504390
# ...                                                 ...         ...
# 2880  [{'credit_id': '52fe4baec3a36847f820f3b1', 'de...   18.826146
# 391   [{'credit_id': '589c5145c3a3684cde007fb5', 'de...   15.772084
# 1694  [{'credit_id': '57160f17c3a3682f450033eb', 'de...   13.165181
# 982   [{'credit_id': '55b5d08892514125da016116', 'de...   15.717618
# 1083  [{'credit_id': '52fe44979251416c7503a275', 'de...   16.523561
# 2959  [{'credit_id': '537ef0d8c3a36805a1002844', 'de...   14.648420
# 2446  [{'credit_id': '52fe435c9251416c7500d6cf', 'de...   15.319588
# 1542  [{'credit_id': '552240b8c3a3684dc1004ef7', 'de...   15.201805
# 395   [{'credit_id': '54ad745f9251417538000081', 'de...    0.000000
# 165   [{'credit_id': '52fe44709251416c91010a89', 'de...    0.000000
# 256   [{'credit_id': '569e12b89251415af100008c', 'de...   17.822844
# 285   [{'credit_id': '537346b60e0a267c5c0014d5', 'de...   17.034386
# 2501  [{'credit_id': '52fe49cb9251416c910b8ebb', 'de...    0.000000
# 365   [{'credit_id': '52fe45e79251416c75066791', 'de...    8.853808
# 1185  [{'credit_id': '52fe43709251416c7501057b', 'de...    0.000000
# 25    [{'credit_id': '54b1fb3b925141144f000991', 'de...    0.000000
# 2728  [{'credit_id': '52fe4b7fc3a36847f82066ef', 'de...    0.000000
# 781   [{'credit_id': '572db56f92514165ec002675', 'de...   16.380460
# 866   [{'credit_id': '52fe4628c3a36847f80f0021', 'de...   11.925042
# 721   [{'credit_id': '52fe4520c3a368484e049edb', 'de...   13.592368
# 90    [{'credit_id': '52fe4210c3a36847f8001049', 'de...   17.216708
# 1840  [{'credit_id': '52fe4946c3a368484e12359b', 'de...   18.683045
# 2650  [{'credit_id': '52fe452d9251416c7504e3ed', 'de...   15.761421
# 2130  [{'credit_id': '52fe43b7c3a36847f8069f4b', 'de...   16.811243
# 254   [{'credit_id': '52fe4a5cc3a368484e14eef3', 'de...    9.321792
# 2040  [{'credit_id': '52fe44e89251416c7504510d', 'de...    0.000000
# 782   [{'credit_id': '52fe4221c3a36847f8006467', 'de...   17.504390
# 2337  [{'credit_id': '52fe44209251416c75029c23', 'de...    0.000000
# 2138  [{'credit_id': '52fe430cc3a36847f80368ed', 'de...   14.346139
# 1453  [{'credit_id': '54e07de7c3a36855c70031c7', 'de...    0.000000
#
#       release_day  release_month  release_year
# 2775            1              9          2011
# 340             4              9          2014
# 2383            1              5          1970
# 519             4              9          2012
# 1122            4              5          1985
# 693             3             10          2014
# 2780            4             12          1995
# 194             5             10          2009
# 821             3              8          1936
# 1818            2              5          2002
# 1733            4              4          2010
# 47              4             12          2015
# 890             4              3          1989
# 2594            2              7          2013
# 2201            3              1          2013
# 2947            3             11          1982
# 936             4              7          2015
# 2886            5              1          2006
# 1107            1              5          2013
# 1710            0             12          1986
# 2563            4              8          2006
# 2670            4             10          2010
# 2285            6             10          2007
# 1880            2              5          2006
# 2614            4             11          2001
# 920             4             11          1987
# 2408            4              2          1991
# 1063            2             12          2005
# 192             4              7          2016
# 1414            4              2          2001
# ...           ...            ...           ...
# 2880            3              6          2013
# 391             2              4          2017
# 1694            4              6          2016
# 982             3              3          2016
# 1083            4              2          2002
# 2959            4             10          2007
# 2446            2              6          1956
# 1542            1              4          1997
# 395             4              1          2008
# 165             6              1          1989
# 256             3              9          2015
# 285             4              3          1996
# 2501            4             12          2012
# 365             4             10          2004
# 1185            3              9          1993
# 25              4             10          1992
# 2728            0             10          1982
# 781             4              2          2016
# 866             1              5          1960
# 721             4              1          2003
# 90              4             10          2003
# 1840            1              2          2014
# 2650            1              3          2008
# 2130            3              4          2013
# 254             2              9          2012
# 2040            4              9          2007
# 782             0             11          1989
# 2337            4             11          1986
# 2138            3              6          1972
# 1453            1              2          2015
#
# [300 rows x 20 columns]

# %% [markdown]
# ### Making my submission

# %%
test.drop(['revenue','log_revenue'],axis=1,inplace=True)
# Out:
# /usr/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
y=np.expm1(model.predict(test))
df_test['revenue']=y
df_test[['Id','revenue']].to_csv('submission.csv',index=False)
